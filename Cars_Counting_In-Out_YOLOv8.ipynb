# %% [markdown]
# ## Object Tracking & Counting YOLOv8

# %%
###############
# PIP Install #
###############

# !pip install yolo
# !pip install ultralytics
# Out:
# Requirement already satisfied: yolo in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (0.3.2)
# Requirement already satisfied: awscli in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from yolo) (1.32.64)
# Requirement already satisfied: boto3 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from yolo) (1.34.64)
# Requirement already satisfied: botocore>=1.7.18 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from yolo) (1.34.64)
# Requirement already satisfied: click in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from yolo) (8.1.3)
# Requirement already satisfied: docker==3.4.0 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from yolo) (3.4.0)
# Requirement already satisfied: jinja2 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from yolo) (3.1.2)
# Requirement already satisfied: keyring==8.7.0 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from yolo) (8.7)
# Requirement already satisfied: keyrings.alt in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from yolo) (5.0.0)
# Requirement already satisfied: requests in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from yolo) (2.28.1)
# Requirement already satisfied: ruamel.yaml in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from yolo) (0.18.6)
# Requirement already satisfied: tabulate in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from yolo) (0.9.0)
# Requirement already satisfied: voluptuous in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from yolo) (0.14.2)
# Requirement already satisfied: six>=1.4.0 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from docker==3.4.0->yolo) (1.16.0)
# Requirement already satisfied: websocket-client>=0.32.0 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from docker==3.4.0->yolo) (1.4.1)
# Requirement already satisfied: docker-pycreds>=0.3.0 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from docker==3.4.0->yolo) (0.4.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from botocore>=1.7.18->yolo) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from botocore>=1.7.18->yolo) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from botocore>=1.7.18->yolo) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from requests->yolo) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from requests->yolo) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from requests->yolo) (2022.9.24)
# Requirement already satisfied: docutils<0.17,>=0.10 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from awscli->yolo) (0.16)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from awscli->yolo) (0.10.1)
# Requirement already satisfied: PyYAML<6.1,>=3.10 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from awscli->yolo) (6.0.1)
# Requirement already satisfied: colorama<0.4.5,>=0.2.5 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from awscli->yolo) (0.4.4)
# Requirement already satisfied: rsa<4.8,>=3.1.2 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from awscli->yolo) (4.7.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jinja2->yolo) (2.1.1)
# Requirement already satisfied: jaraco.classes in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from keyrings.alt->yolo) (3.3.1)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ruamel.yaml->yolo) (0.2.8)
# Requirement already satisfied: pyasn1>=0.1.3 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from rsa<4.8,>=3.1.2->awscli->yolo) (0.4.8)
# Requirement already satisfied: more-itertools in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jaraco.classes->keyrings.alt->yolo) (10.2.0)
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Requirement already satisfied: ultralytics in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (8.1.29)
# Requirement already satisfied: matplotlib>=3.3.0 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ultralytics) (3.8.3)
# Requirement already satisfied: opencv-python>=4.6.0 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ultralytics) (4.9.0.80)
# Requirement already satisfied: pillow>=7.1.2 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ultralytics) (9.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ultralytics) (2.28.1)
# Requirement already satisfied: scipy>=1.4.1 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ultralytics) (1.12.0)
# Requirement already satisfied: torch>=1.8.0 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ultralytics) (1.13.0)
# Requirement already satisfied: torchvision>=0.9.0 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ultralytics) (0.14.0)
# Requirement already satisfied: tqdm>=4.64.0 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ultralytics) (4.64.1)
# Requirement already satisfied: psutil in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ultralytics) (5.9.3)
# Requirement already satisfied: py-cpuinfo in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: thop>=0.1.1 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ultralytics) (0.1.1.post2209072238)
# Requirement already satisfied: pandas>=1.1.4 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ultralytics) (1.4.4)
# Requirement already satisfied: seaborn>=0.11.0 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ultralytics) (0.11.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.21 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2022.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2022.9.24)
# Requirement already satisfied: typing-extensions in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (4.8.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (11.7.99)
# Requirement already satisfied: setuptools in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.8.0->ultralytics) (69.2.0)
# Requirement already satisfied: wheel in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.8.0->ultralytics) (0.43.0)
# Requirement already satisfied: six>=1.5 in /home/valerio/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python3.10 -m pip install --upgrade pip

# %%
###########
# Imports #
###########

import cv2
import numpy as np
from ultralytics import YOLO
from ultralytics.utils.plotting import Annotator, colors

# %%
######################
# Parameters & model #
######################

## Initialize IDs sets ##
car_ids = set()
truck_ids = set()

## Dictionary to track the last known Y position of each ID ##
last_positions = {}

car_in, car_out, truck_in, truck_out = 0, 0, 0, 0

## Initialize segmentation model ##
model = YOLO("yolov8l-seg.pt")
filename = "video001"

## Create VideoCapture object ##
cap = cv2.VideoCapture(f"/home/valerio/code/ValerioCann/Modèles/Data/Videos//{filename}.mp4")

## Retrieve height, widht & frame per second ##
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

## Create VideoWriter object ##
out = cv2.VideoWriter(f'{filename}.avi', cv2.VideoWriter_fourcc(*'MJPG'), fps, (w, h))


##########################
# Tracking & Annotations #
##########################

# Sets a horizontal line in the middle of the image for counting
line_y = h // 2
        
while True:
    ret, im0 = cap.read()
    if not ret:
        print("Video frame is empty or video processing has been successfully completed.")
        break
        
    ## instantiates annotator ##
    annotator = Annotator(im0, line_width=2)
    
    ## Track objects ##
    results = model.track(im0, persist=True)

    ## Retrieve masks & track ids ##
    if results[0].boxes.id is not None and results[0].masks is not None:
        masks = results[0].masks.xy
        track_ids = results[0].boxes.id.int().cpu().tolist()

        
        ## Draws segmentation boxes on detected objects ##
        for mask, track_id in zip(masks, track_ids):
            ## Calculation of the central position of the vehicle (we will use the center of the mask) ##
            center_y = int(np.mean(np.array(mask)[:, 1]))  # Average of mask Y coordinates

            # Checks if the vehicle has already been tracked
            if track_id in last_positions:
                # Determines direction based on previous position
                if last_positions[track_id] < line_y <= center_y:
                    # Vehicle moves down - IN
                    if track_id in car_ids: car_in += 1
                    else: truck_in += 1
                elif last_positions[track_id] > line_y >= center_y:
                    # Vehicle moves up - OUT
                    if track_id in car_ids: car_out += 1
                    else: truck_out += 1

            # Updating the vehicle's last known position
            last_positions[track_id] = center_y
            annotator.seg_bbox(mask=mask,
                               mask_color=colors(track_id, True),
                               track_label=str(track_id))

            # Keep track of unique car and truck IDs
            if track_id not in car_ids and track_id not in truck_ids:
                area = cv2.contourArea(mask)
                if area > 50000:  # Adjust threshold for distinguishing between cars and trucks
                    truck_ids.add(track_id)
                else:
                    car_ids.add(track_id)

    
###################
# Text parameters #
###################


    ## Font size for text ##
    fontScale = 2.0  
    
    ## Space around text in rectangle ##
    padding = 10  
    
    line_spacing = 20
    
    ## Text thickness ##
    thickness = 3
    
    ## Text ##
    text_cars = f"Cars IN: {car_in}, Cars OUT: {car_out}"
    text_trucks = f"Trucks IN: {truck_in}, Trucks OUT: {truck_out}"
    
    ## Get text size ##
    (text_width_cars, text_height_cars), _ = cv2.getTextSize(text_cars, cv2.FONT_HERSHEY_SIMPLEX, fontScale, 2)
    (text_width_trucks, text_height_trucks), _ = cv2.getTextSize(text_trucks, cv2.FONT_HERSHEY_SIMPLEX, fontScale, 2)

    ## Calculating the total width and height needed for the rectangle ##
    total_text_width = max(text_width_cars, text_width_trucks)
    total_text_height = text_height_cars + text_height_trucks + padding + line_spacing  # Ajoutez un peu d'espace (padding) entre les lignes
    
    ## Coordinates of the rectangle around the text ##
    rectangle_top_left = (0, 0)  # En haut à gauche de l'image
    rectangle_bottom_right = (total_text_width + 2 * padding, total_text_height + 3 * padding + 10)

    ## Rectangle color - BGR ##
    rectangle_color = (0, 0, 255) 

    ## Draw the rectangle ##
    cv2.rectangle(im0, rectangle_top_left, rectangle_bottom_right, rectangle_color, cv2.FILLED)
    
    ## Text color - BGR ##
    text_color = (255, 255, 255)
    
    ## Add text ##
    cv2.putText(im0, text_cars, (padding, text_height_cars + padding), cv2.FONT_HERSHEY_SIMPLEX, fontScale, text_color, 2, cv2.LINE_AA)
    cv2.putText(im0, text_trucks, (padding, 2 * text_height_cars + 2 * padding + line_spacing), cv2.FONT_HERSHEY_SIMPLEX, fontScale, text_color, 2, cv2.LINE_AA)

    
#############################################
# Output video creation, saving and display #
#############################################


    ## Draw the counting line on the image ##
    cv2.line(im0, (0, line_y), (w, line_y), (0, 0, 255), 3)  # Ligne jaune

    ## Adds a new frame to the output video ##
    out.write(im0)
    
    ## displays the frame ##
    cv2.imshow("instance-segmentation-object-tracking", im0)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

out.release()
cap.release()
cv2.destroyAllWindows()
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.1.0/yolov8l-seg.pt to 'yolov8l-seg.pt'...
#   0%|          | 0.00/88.1M [00:00<?, ?B/s]
# 0: 384x640 8 cars, 5 trucks, 797.6ms
# Speed: 5.6ms preprocess, 797.6ms inference, 19.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 trucks, 793.9ms
# Speed: 4.3ms preprocess, 793.9ms inference, 14.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 trucks, 674.7ms
# Speed: 1.9ms preprocess, 674.7ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 trucks, 654.8ms
# Speed: 1.9ms preprocess, 654.8ms inference, 12.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 trucks, 1 stop sign, 675.1ms
# Speed: 2.6ms preprocess, 675.1ms inference, 16.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 trucks, 1 stop sign, 553.4ms
# Speed: 2.0ms preprocess, 553.4ms inference, 12.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 trucks, 1 stop sign, 627.7ms
# Speed: 4.6ms preprocess, 627.7ms inference, 12.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 trucks, 1 stop sign, 595.1ms
# Speed: 1.9ms preprocess, 595.1ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 trucks, 1 stop sign, 565.1ms
# Speed: 1.8ms preprocess, 565.1ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 trucks, 1 stop sign, 687.8ms
# Speed: 2.6ms preprocess, 687.8ms inference, 11.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 trucks, 1 stop sign, 540.0ms
# Speed: 1.8ms preprocess, 540.0ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 trucks, 1 stop sign, 622.4ms
# Speed: 8.3ms preprocess, 622.4ms inference, 11.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 trucks, 1 stop sign, 591.2ms
# Speed: 2.5ms preprocess, 591.2ms inference, 9.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 6 trucks, 1 stop sign, 618.9ms
# Speed: 2.3ms preprocess, 618.9ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 trucks, 1 stop sign, 560.4ms
# Speed: 2.2ms preprocess, 560.4ms inference, 10.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 trucks, 1 stop sign, 574.6ms
# Speed: 1.9ms preprocess, 574.6ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 trucks, 1 stop sign, 597.7ms
# Speed: 1.9ms preprocess, 597.7ms inference, 11.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 trucks, 1 stop sign, 610.7ms
# Speed: 2.1ms preprocess, 610.7ms inference, 10.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 trucks, 1 stop sign, 562.1ms
# Speed: 3.6ms preprocess, 562.1ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 trucks, 1 stop sign, 633.5ms
# Speed: 2.0ms preprocess, 633.5ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 trucks, 1 stop sign, 658.4ms
# Speed: 3.1ms preprocess, 658.4ms inference, 10.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 5 trucks, 1 stop sign, 663.9ms
# Speed: 3.0ms preprocess, 663.9ms inference, 18.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 5 trucks, 1 stop sign, 619.9ms
# Speed: 1.8ms preprocess, 619.9ms inference, 9.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 5 trucks, 1 stop sign, 639.7ms
# Speed: 4.2ms preprocess, 639.7ms inference, 11.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 5 trucks, 1 stop sign, 537.7ms
# Speed: 4.2ms preprocess, 537.7ms inference, 11.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 5 trucks, 1 stop sign, 579.9ms
# Speed: 3.9ms preprocess, 579.9ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 5 trucks, 1 stop sign, 620.9ms
# Speed: 2.2ms preprocess, 620.9ms inference, 13.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 5 trucks, 1 stop sign, 603.9ms
# Speed: 2.2ms preprocess, 603.9ms inference, 11.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 8 cars, 5 trucks, 1 stop sign, 589.5ms
# Speed: 8.3ms preprocess, 589.5ms inference, 9.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 5 trucks, 1 stop sign, 563.7ms
# Speed: 5.4ms preprocess, 563.7ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 5 trucks, 1 stop sign, 467.0ms
# Speed: 2.4ms preprocess, 467.0ms inference, 9.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 5 trucks, 1 stop sign, 672.5ms
# Speed: 4.5ms preprocess, 672.5ms inference, 12.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 5 trucks, 1 stop sign, 663.4ms
# Speed: 3.6ms preprocess, 663.4ms inference, 11.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 5 trucks, 1 stop sign, 729.1ms
# Speed: 2.6ms preprocess, 729.1ms inference, 13.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 5 trucks, 1 stop sign, 581.7ms
# Speed: 2.7ms preprocess, 581.7ms inference, 9.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 5 trucks, 1 stop sign, 542.7ms
# Speed: 3.0ms preprocess, 542.7ms inference, 9.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 5 trucks, 1 stop sign, 602.0ms
# Speed: 3.5ms preprocess, 602.0ms inference, 10.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 5 trucks, 1 stop sign, 597.1ms
# Speed: 5.4ms preprocess, 597.1ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 6 trucks, 676.2ms
# Speed: 2.6ms preprocess, 676.2ms inference, 11.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 6 trucks, 585.5ms
# Speed: 5.2ms preprocess, 585.5ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 6 trucks, 560.8ms
# Speed: 3.5ms preprocess, 560.8ms inference, 10.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 6 trucks, 652.0ms
# Speed: 2.9ms preprocess, 652.0ms inference, 9.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 6 trucks, 637.5ms
# Speed: 4.0ms preprocess, 637.5ms inference, 10.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 6 trucks, 553.5ms
# Speed: 2.3ms preprocess, 553.5ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 6 trucks, 586.2ms
# Speed: 2.6ms preprocess, 586.2ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 6 trucks, 629.6ms
# Speed: 3.3ms preprocess, 629.6ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 6 trucks, 627.9ms
# Speed: 4.7ms preprocess, 627.9ms inference, 11.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 6 trucks, 624.1ms
# Speed: 5.6ms preprocess, 624.1ms inference, 10.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 6 trucks, 585.8ms
# Speed: 2.6ms preprocess, 585.8ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 6 trucks, 565.6ms
# Speed: 3.4ms preprocess, 565.6ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 6 trucks, 608.4ms
# Speed: 3.2ms preprocess, 608.4ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 6 trucks, 602.6ms
# Speed: 5.0ms preprocess, 602.6ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 7 trucks, 606.2ms
# Speed: 4.9ms preprocess, 606.2ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 7 trucks, 633.0ms
# Speed: 2.9ms preprocess, 633.0ms inference, 11.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 7 trucks, 552.4ms
# Speed: 2.6ms preprocess, 552.4ms inference, 10.4ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 person, 7 cars, 7 trucks, 616.1ms
# Speed: 4.6ms preprocess, 616.1ms inference, 9.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 7 trucks, 578.3ms
# Speed: 2.2ms preprocess, 578.3ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 7 trucks, 644.2ms
# Speed: 2.6ms preprocess, 644.2ms inference, 9.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 7 trucks, 602.3ms
# Speed: 3.7ms preprocess, 602.3ms inference, 9.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 7 trucks, 646.1ms
# Speed: 2.3ms preprocess, 646.1ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 7 trucks, 597.6ms
# Speed: 2.9ms preprocess, 597.6ms inference, 9.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 cars, 7 trucks, 608.5ms
# Speed: 2.5ms preprocess, 608.5ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 7 trucks, 634.0ms
# Speed: 3.0ms preprocess, 634.0ms inference, 9.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 7 trucks, 656.7ms
# Speed: 3.0ms preprocess, 656.7ms inference, 11.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 7 trucks, 632.3ms
# Speed: 3.2ms preprocess, 632.3ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 8 trucks, 567.5ms
# Speed: 5.3ms preprocess, 567.5ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 7 trucks, 645.4ms
# Speed: 2.6ms preprocess, 645.4ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 8 trucks, 478.1ms
# Speed: 4.9ms preprocess, 478.1ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 7 trucks, 609.7ms
# Speed: 4.4ms preprocess, 609.7ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 7 trucks, 649.5ms
# Speed: 2.3ms preprocess, 649.5ms inference, 9.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 7 trucks, 644.5ms
# Speed: 3.9ms preprocess, 644.5ms inference, 9.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 7 trucks, 622.4ms
# Speed: 2.2ms preprocess, 622.4ms inference, 9.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 8 trucks, 689.3ms
# Speed: 2.8ms preprocess, 689.3ms inference, 9.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 7 trucks, 703.2ms
# Speed: 5.1ms preprocess, 703.2ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 8 trucks, 609.1ms
# Speed: 2.2ms preprocess, 609.1ms inference, 9.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 7 trucks, 590.4ms
# Speed: 2.9ms preprocess, 590.4ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 7 trucks, 657.9ms
# Speed: 4.7ms preprocess, 657.9ms inference, 9.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 7 trucks, 643.6ms
# Speed: 2.4ms preprocess, 643.6ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 8 trucks, 558.7ms
# Speed: 3.6ms preprocess, 558.7ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 9 trucks, 594.8ms
# Speed: 3.3ms preprocess, 594.8ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 9 trucks, 503.3ms
# Speed: 2.8ms preprocess, 503.3ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 9 trucks, 580.5ms
# Speed: 2.1ms preprocess, 580.5ms inference, 9.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 9 trucks, 598.7ms
# Speed: 2.1ms preprocess, 598.7ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 8 trucks, 525.3ms
# Speed: 4.6ms preprocess, 525.3ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 8 trucks, 609.9ms
# Speed: 4.1ms preprocess, 609.9ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 8 trucks, 622.0ms
# Speed: 3.6ms preprocess, 622.0ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 8 trucks, 676.7ms
# Speed: 3.0ms preprocess, 676.7ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 8 trucks, 585.3ms
# Speed: 4.3ms preprocess, 585.3ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 8 trucks, 630.3ms
# Speed: 5.3ms preprocess, 630.3ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 8 trucks, 548.6ms
# Speed: 4.0ms preprocess, 548.6ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 8 trucks, 583.0ms
# Speed: 3.7ms preprocess, 583.0ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 8 trucks, 553.4ms
# Speed: 2.8ms preprocess, 553.4ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 8 trucks, 605.9ms
# Speed: 3.7ms preprocess, 605.9ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 9 trucks, 610.9ms
# Speed: 2.6ms preprocess, 610.9ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 9 trucks, 643.2ms
# Speed: 5.1ms preprocess, 643.2ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 9 trucks, 705.2ms
# Speed: 3.6ms preprocess, 705.2ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 9 trucks, 577.1ms
# Speed: 2.6ms preprocess, 577.1ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 9 trucks, 635.2ms
# Speed: 4.9ms preprocess, 635.2ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 8 trucks, 675.3ms
# Speed: 5.7ms preprocess, 675.3ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 9 trucks, 714.4ms
# Speed: 3.7ms preprocess, 714.4ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 9 trucks, 666.2ms
# Speed: 4.5ms preprocess, 666.2ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 8 trucks, 638.0ms
# Speed: 3.9ms preprocess, 638.0ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 9 trucks, 617.0ms
# Speed: 4.5ms preprocess, 617.0ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 7 trucks, 630.7ms
# Speed: 1.9ms preprocess, 630.7ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 9 trucks, 604.9ms
# Speed: 2.8ms preprocess, 604.9ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 9 trucks, 595.0ms
# Speed: 1.9ms preprocess, 595.0ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 9 trucks, 590.6ms
# Speed: 6.0ms preprocess, 590.6ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 9 trucks, 654.7ms
# Speed: 2.4ms preprocess, 654.7ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 9 trucks, 720.6ms
# Speed: 2.1ms preprocess, 720.6ms inference, 9.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 9 trucks, 625.7ms
# Speed: 3.2ms preprocess, 625.7ms inference, 9.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 9 trucks, 689.4ms
# Speed: 2.3ms preprocess, 689.4ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 8 trucks, 596.5ms
# Speed: 4.7ms preprocess, 596.5ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 9 trucks, 602.1ms
# Speed: 4.1ms preprocess, 602.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 9 trucks, 650.3ms
# Speed: 3.2ms preprocess, 650.3ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 8 trucks, 639.6ms
# Speed: 3.2ms preprocess, 639.6ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 6 cars, 9 trucks, 617.1ms
# Speed: 2.6ms preprocess, 617.1ms inference, 9.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 9 trucks, 546.0ms
# Speed: 3.5ms preprocess, 546.0ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 7 trucks, 631.2ms
# Speed: 4.7ms preprocess, 631.2ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 8 trucks, 589.0ms
# Speed: 5.2ms preprocess, 589.0ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 8 trucks, 583.5ms
# Speed: 3.1ms preprocess, 583.5ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 8 trucks, 590.5ms
# Speed: 2.3ms preprocess, 590.5ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 8 trucks, 566.7ms
# Speed: 2.6ms preprocess, 566.7ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 8 trucks, 667.9ms
# Speed: 3.2ms preprocess, 667.9ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 8 trucks, 629.2ms
# Speed: 3.7ms preprocess, 629.2ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 7 trucks, 667.8ms
# Speed: 5.8ms preprocess, 667.8ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 8 trucks, 609.2ms
# Speed: 5.9ms preprocess, 609.2ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 6 trucks, 622.1ms
# Speed: 2.6ms preprocess, 622.1ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 8 trucks, 727.2ms
# Speed: 5.6ms preprocess, 727.2ms inference, 9.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 6 trucks, 609.7ms
# Speed: 1.9ms preprocess, 609.7ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 7 trucks, 647.3ms
# Speed: 2.4ms preprocess, 647.3ms inference, 9.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 7 trucks, 621.3ms
# Speed: 2.0ms preprocess, 621.3ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 7 trucks, 612.8ms
# Speed: 3.0ms preprocess, 612.8ms inference, 9.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 7 trucks, 651.3ms
# Speed: 1.9ms preprocess, 651.3ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 trucks, 643.1ms
# Speed: 4.3ms preprocess, 643.1ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 6 trucks, 618.6ms
# Speed: 2.5ms preprocess, 618.6ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 trucks, 678.4ms
# Speed: 3.0ms preprocess, 678.4ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 trucks, 630.1ms
# Speed: 2.1ms preprocess, 630.1ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 6 trucks, 675.3ms
# Speed: 3.7ms preprocess, 675.3ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 6 trucks, 609.1ms
# Speed: 3.3ms preprocess, 609.1ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 7 trucks, 576.1ms
# Speed: 1.8ms preprocess, 576.1ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 6 trucks, 1 stop sign, 655.6ms
# Speed: 4.1ms preprocess, 655.6ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 trucks, 1 stop sign, 571.0ms
# Speed: 2.4ms preprocess, 571.0ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 trucks, 1 stop sign, 615.0ms
# Speed: 4.4ms preprocess, 615.0ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 6 trucks, 1 stop sign, 634.8ms
# Speed: 2.4ms preprocess, 634.8ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 6 trucks, 1 stop sign, 548.4ms
# Speed: 2.5ms preprocess, 548.4ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 6 trucks, 1 stop sign, 629.6ms
# Speed: 2.7ms preprocess, 629.6ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 6 trucks, 1 stop sign, 627.8ms
# Speed: 2.7ms preprocess, 627.8ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 6 trucks, 1 stop sign, 510.5ms
# Speed: 2.3ms preprocess, 510.5ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 trucks, 1 stop sign, 614.2ms
# Speed: 4.6ms preprocess, 614.2ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 6 trucks, 1 stop sign, 662.0ms
# Speed: 3.5ms preprocess, 662.0ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 6 trucks, 1 stop sign, 674.1ms
# Speed: 2.2ms preprocess, 674.1ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 trucks, 519.3ms
# Speed: 3.0ms preprocess, 519.3ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 trucks, 617.8ms
# Speed: 3.0ms preprocess, 617.8ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 6 trucks, 576.5ms
# Speed: 5.3ms preprocess, 576.5ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 trucks, 601.2ms
# Speed: 4.5ms preprocess, 601.2ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 trucks, 1 stop sign, 658.6ms
# Speed: 2.6ms preprocess, 658.6ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 5 trucks, 1 stop sign, 647.4ms
# Speed: 3.6ms preprocess, 647.4ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 trucks, 1 stop sign, 558.8ms
# Speed: 4.0ms preprocess, 558.8ms inference, 9.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 trucks, 1 stop sign, 603.6ms
# Speed: 3.0ms preprocess, 603.6ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 trucks, 1 stop sign, 645.3ms
# Speed: 3.4ms preprocess, 645.3ms inference, 10.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 6 trucks, 1 stop sign, 574.2ms
# Speed: 3.4ms preprocess, 574.2ms inference, 10.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 trucks, 1 stop sign, 530.2ms
# Speed: 3.5ms preprocess, 530.2ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 trucks, 1 stop sign, 610.8ms
# Speed: 4.8ms preprocess, 610.8ms inference, 10.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 7 trucks, 1 stop sign, 622.8ms
# Speed: 3.4ms preprocess, 622.8ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 trucks, 1 stop sign, 626.2ms
# Speed: 2.7ms preprocess, 626.2ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 6 trucks, 1 stop sign, 585.4ms
# Speed: 2.5ms preprocess, 585.4ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 trucks, 1 stop sign, 569.2ms
# Speed: 3.5ms preprocess, 569.2ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 trucks, 1 stop sign, 578.7ms
# Speed: 4.9ms preprocess, 578.7ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 6 trucks, 1 stop sign, 552.0ms
# Speed: 3.1ms preprocess, 552.0ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 6 trucks, 1 stop sign, 627.2ms
# Speed: 3.6ms preprocess, 627.2ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 6 trucks, 1 stop sign, 617.3ms
# Speed: 3.3ms preprocess, 617.3ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 6 trucks, 1 stop sign, 604.2ms
# Speed: 2.5ms preprocess, 604.2ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 7 trucks, 644.3ms
# Speed: 4.7ms preprocess, 644.3ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 8 cars, 7 trucks, 555.7ms
# Speed: 4.5ms preprocess, 555.7ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 6 trucks, 612.3ms
# Speed: 2.7ms preprocess, 612.3ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 7 trucks, 665.2ms
# Speed: 4.5ms preprocess, 665.2ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 7 trucks, 661.7ms
# Speed: 2.4ms preprocess, 661.7ms inference, 11.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 6 trucks, 688.8ms
# Speed: 3.3ms preprocess, 688.8ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 7 trucks, 1 stop sign, 709.2ms
# Speed: 5.2ms preprocess, 709.2ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 5 trucks, 1 stop sign, 698.0ms
# Speed: 2.5ms preprocess, 698.0ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 6 trucks, 1 stop sign, 633.5ms
# Speed: 2.2ms preprocess, 633.5ms inference, 10.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 6 trucks, 1 stop sign, 650.6ms
# Speed: 2.7ms preprocess, 650.6ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 5 trucks, 616.1ms
# Speed: 3.5ms preprocess, 616.1ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 5 trucks, 596.5ms
# Speed: 4.6ms preprocess, 596.5ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 5 trucks, 601.9ms
# Speed: 2.7ms preprocess, 601.9ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 5 trucks, 664.9ms
# Speed: 2.6ms preprocess, 664.9ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 6 trucks, 549.2ms
# Speed: 2.3ms preprocess, 549.2ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 7 trucks, 561.2ms
# Speed: 5.3ms preprocess, 561.2ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 7 trucks, 681.6ms
# Speed: 2.5ms preprocess, 681.6ms inference, 9.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 6 trucks, 622.7ms
# Speed: 3.2ms preprocess, 622.7ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 6 trucks, 616.4ms
# Speed: 2.7ms preprocess, 616.4ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 5 trucks, 586.4ms
# Speed: 2.7ms preprocess, 586.4ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 5 trucks, 668.3ms
# Speed: 5.3ms preprocess, 668.3ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 5 trucks, 558.4ms
# Speed: 2.2ms preprocess, 558.4ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 5 trucks, 560.4ms
# Speed: 3.7ms preprocess, 560.4ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 5 trucks, 597.8ms
# Speed: 5.1ms preprocess, 597.8ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 5 trucks, 613.6ms
# Speed: 3.1ms preprocess, 613.6ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 5 trucks, 584.3ms
# Speed: 3.9ms preprocess, 584.3ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 5 trucks, 634.4ms
# Speed: 4.6ms preprocess, 634.4ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 5 trucks, 604.5ms
# Speed: 5.5ms preprocess, 604.5ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 5 trucks, 667.2ms
# Speed: 2.2ms preprocess, 667.2ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 5 trucks, 670.0ms
# Speed: 3.6ms preprocess, 670.0ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 5 trucks, 563.4ms
# Speed: 3.4ms preprocess, 563.4ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 5 trucks, 629.4ms
# Speed: 5.2ms preprocess, 629.4ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 5 trucks, 645.5ms
# Speed: 3.7ms preprocess, 645.5ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 5 trucks, 609.8ms
# Speed: 2.4ms preprocess, 609.8ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 5 trucks, 649.3ms
# Speed: 3.4ms preprocess, 649.3ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 5 trucks, 627.5ms
# Speed: 2.1ms preprocess, 627.5ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 5 trucks, 1 stop sign, 595.5ms
# Speed: 2.3ms preprocess, 595.5ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 6 trucks, 1 stop sign, 592.9ms
# Speed: 2.3ms preprocess, 592.9ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 5 trucks, 1 stop sign, 543.0ms
# Speed: 3.9ms preprocess, 543.0ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 5 trucks, 1 stop sign, 584.8ms
# Speed: 3.3ms preprocess, 584.8ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 5 trucks, 1 stop sign, 573.6ms
# Speed: 2.7ms preprocess, 573.6ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 6 trucks, 1 stop sign, 612.7ms
# Speed: 4.8ms preprocess, 612.7ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 6 trucks, 600.4ms
# Speed: 3.5ms preprocess, 600.4ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 6 trucks, 569.8ms
# Speed: 2.5ms preprocess, 569.8ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 6 trucks, 599.0ms
# Speed: 5.2ms preprocess, 599.0ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 6 trucks, 607.2ms
# Speed: 2.4ms preprocess, 607.2ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 6 trucks, 578.0ms
# Speed: 2.3ms preprocess, 578.0ms inference, 9.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 6 trucks, 1 stop sign, 621.7ms
# Speed: 3.7ms preprocess, 621.7ms inference, 10.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 6 trucks, 1 stop sign, 643.7ms
# Speed: 5.8ms preprocess, 643.7ms inference, 10.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 7 trucks, 1 stop sign, 607.6ms
# Speed: 2.5ms preprocess, 607.6ms inference, 10.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 6 trucks, 1 stop sign, 593.9ms
# Speed: 3.4ms preprocess, 593.9ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 6 trucks, 1 stop sign, 631.5ms
# Speed: 4.9ms preprocess, 631.5ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 7 trucks, 1 stop sign, 586.2ms
# Speed: 3.1ms preprocess, 586.2ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 7 trucks, 1 stop sign, 549.5ms
# Speed: 4.6ms preprocess, 549.5ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 7 trucks, 1 stop sign, 598.3ms
# Speed: 5.4ms preprocess, 598.3ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 7 trucks, 1 stop sign, 551.2ms
# Speed: 2.5ms preprocess, 551.2ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 7 trucks, 1 stop sign, 623.0ms
# Speed: 2.3ms preprocess, 623.0ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 7 trucks, 1 stop sign, 594.9ms
# Speed: 3.2ms preprocess, 594.9ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 8 trucks, 1 stop sign, 604.5ms
# Speed: 2.5ms preprocess, 604.5ms inference, 10.2ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 9 cars, 7 trucks, 1 stop sign, 683.2ms
# Speed: 3.6ms preprocess, 683.2ms inference, 11.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 7 trucks, 1 stop sign, 664.3ms
# Speed: 2.2ms preprocess, 664.3ms inference, 9.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 7 trucks, 1 stop sign, 613.9ms
# Speed: 4.7ms preprocess, 613.9ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 7 trucks, 1 stop sign, 562.5ms
# Speed: 2.5ms preprocess, 562.5ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 7 trucks, 1 stop sign, 626.5ms
# Speed: 2.7ms preprocess, 626.5ms inference, 9.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 6 trucks, 1 stop sign, 679.0ms
# Speed: 2.4ms preprocess, 679.0ms inference, 9.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 7 trucks, 1 stop sign, 529.5ms
# Speed: 2.3ms preprocess, 529.5ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 7 trucks, 1 stop sign, 603.3ms
# Speed: 4.9ms preprocess, 603.3ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 7 trucks, 1 stop sign, 640.3ms
# Speed: 2.5ms preprocess, 640.3ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 7 trucks, 1 stop sign, 618.7ms
# Speed: 3.2ms preprocess, 618.7ms inference, 9.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 6 trucks, 1 stop sign, 627.6ms
# Speed: 2.9ms preprocess, 627.6ms inference, 9.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 7 trucks, 1 stop sign, 668.8ms
# Speed: 2.4ms preprocess, 668.8ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 6 trucks, 1 stop sign, 605.6ms
# Speed: 2.6ms preprocess, 605.6ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 6 trucks, 1 stop sign, 691.9ms
# Speed: 4.8ms preprocess, 691.9ms inference, 9.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 6 trucks, 1 stop sign, 637.0ms
# Speed: 4.2ms preprocess, 637.0ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 6 trucks, 1 stop sign, 507.2ms
# Speed: 3.6ms preprocess, 507.2ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 7 trucks, 1 stop sign, 528.2ms
# Speed: 5.1ms preprocess, 528.2ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 7 trucks, 1 stop sign, 619.2ms
# Speed: 2.3ms preprocess, 619.2ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 7 trucks, 1 stop sign, 615.0ms
# Speed: 2.8ms preprocess, 615.0ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 7 trucks, 1 stop sign, 663.1ms
# Speed: 2.1ms preprocess, 663.1ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 7 trucks, 1 stop sign, 702.8ms
# Speed: 5.1ms preprocess, 702.8ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 7 trucks, 1 stop sign, 691.7ms
# Speed: 4.5ms preprocess, 691.7ms inference, 10.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 7 trucks, 1 stop sign, 621.5ms
# Speed: 2.4ms preprocess, 621.5ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 7 trucks, 1 stop sign, 668.5ms
# Speed: 2.3ms preprocess, 668.5ms inference, 9.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 7 trucks, 1 stop sign, 659.4ms
# Speed: 5.7ms preprocess, 659.4ms inference, 9.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 7 trucks, 1 stop sign, 556.3ms
# Speed: 2.4ms preprocess, 556.3ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 7 trucks, 1 stop sign, 670.6ms
# Speed: 5.0ms preprocess, 670.6ms inference, 9.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 7 trucks, 1 stop sign, 553.8ms
# Speed: 4.1ms preprocess, 553.8ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 7 trucks, 1 stop sign, 632.0ms
# Speed: 2.2ms preprocess, 632.0ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 7 trucks, 1 stop sign, 651.7ms
# Speed: 2.6ms preprocess, 651.7ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 6 trucks, 1 stop sign, 629.6ms
# Speed: 2.7ms preprocess, 629.6ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 6 trucks, 1 stop sign, 604.6ms
# Speed: 4.4ms preprocess, 604.6ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 6 trucks, 1 stop sign, 594.5ms
# Speed: 2.7ms preprocess, 594.5ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 6 trucks, 1 stop sign, 648.7ms
# Speed: 2.1ms preprocess, 648.7ms inference, 9.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 6 trucks, 1 stop sign, 615.0ms
# Speed: 2.6ms preprocess, 615.0ms inference, 9.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 6 trucks, 1 stop sign, 628.9ms
# Speed: 2.7ms preprocess, 628.9ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 6 trucks, 1 stop sign, 596.6ms
# Speed: 3.5ms preprocess, 596.6ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 6 trucks, 1 stop sign, 595.5ms
# Speed: 5.0ms preprocess, 595.5ms inference, 10.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 5 trucks, 1 stop sign, 679.0ms
# Speed: 2.6ms preprocess, 679.0ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 6 trucks, 1 stop sign, 613.1ms
# Speed: 4.5ms preprocess, 613.1ms inference, 9.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 6 trucks, 1 stop sign, 699.1ms
# Speed: 3.4ms preprocess, 699.1ms inference, 10.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 6 trucks, 1 stop sign, 732.8ms
# Speed: 2.6ms preprocess, 732.8ms inference, 9.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 6 trucks, 1 stop sign, 648.2ms
# Speed: 2.2ms preprocess, 648.2ms inference, 9.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 6 trucks, 1 stop sign, 573.0ms
# Speed: 4.8ms preprocess, 573.0ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 6 trucks, 1 stop sign, 629.7ms
# Speed: 4.6ms preprocess, 629.7ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 6 trucks, 1 stop sign, 600.3ms
# Speed: 4.7ms preprocess, 600.3ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 6 trucks, 1 stop sign, 587.2ms
# Speed: 4.8ms preprocess, 587.2ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 6 trucks, 627.7ms
# Speed: 2.4ms preprocess, 627.7ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 6 trucks, 630.6ms
# Speed: 2.3ms preprocess, 630.6ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 6 trucks, 551.3ms
# Speed: 2.8ms preprocess, 551.3ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 6 trucks, 550.6ms
# Speed: 2.2ms preprocess, 550.6ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 6 trucks, 651.5ms
# Speed: 2.1ms preprocess, 651.5ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 6 trucks, 520.9ms
# Speed: 4.6ms preprocess, 520.9ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 6 trucks, 526.1ms
# Speed: 2.7ms preprocess, 526.1ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 6 trucks, 630.5ms
# Speed: 2.4ms preprocess, 630.5ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 trucks, 628.5ms
# Speed: 2.2ms preprocess, 628.5ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 7 cars, 6 trucks, 660.3ms
# Speed: 2.7ms preprocess, 660.3ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 6 trucks, 642.6ms
# Speed: 5.0ms preprocess, 642.6ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 6 trucks, 618.8ms
# Speed: 2.6ms preprocess, 618.8ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 6 trucks, 573.4ms
# Speed: 2.9ms preprocess, 573.4ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 7 trucks, 625.5ms
# Speed: 1.9ms preprocess, 625.5ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 7 trucks, 1 stop sign, 662.2ms
# Speed: 4.5ms preprocess, 662.2ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 7 trucks, 1 stop sign, 608.5ms
# Speed: 4.8ms preprocess, 608.5ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 7 trucks, 1 stop sign, 626.7ms
# Speed: 2.7ms preprocess, 626.7ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 7 trucks, 1 stop sign, 595.6ms
# Speed: 3.0ms preprocess, 595.6ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 7 trucks, 1 stop sign, 602.5ms
# Speed: 2.4ms preprocess, 602.5ms inference, 11.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 7 trucks, 1 stop sign, 495.2ms
# Speed: 2.4ms preprocess, 495.2ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 7 trucks, 1 stop sign, 649.4ms
# Speed: 4.6ms preprocess, 649.4ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 6 trucks, 1 stop sign, 640.9ms
# Speed: 2.5ms preprocess, 640.9ms inference, 12.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 7 trucks, 1 stop sign, 636.2ms
# Speed: 3.2ms preprocess, 636.2ms inference, 10.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 6 trucks, 1 stop sign, 515.4ms
# Speed: 2.4ms preprocess, 515.4ms inference, 10.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 7 trucks, 1 stop sign, 626.0ms
# Speed: 2.4ms preprocess, 626.0ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 7 trucks, 573.9ms
# Speed: 2.4ms preprocess, 573.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 7 trucks, 667.8ms
# Speed: 2.5ms preprocess, 667.8ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 6 trucks, 624.7ms
# Speed: 2.3ms preprocess, 624.7ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 6 trucks, 542.3ms
# Speed: 2.3ms preprocess, 542.3ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 640)
# Video frame is empty or video processing has been successfully completed.
